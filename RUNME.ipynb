# %% [markdown]
# <a href="https://colab.research.google.com/github/x1001000/nss-report-v154-fix/blob/main/RUNME.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/x1001000/nss-report-v154-fix
# %cd nss-report-v154-fix/Report
# !pip install PyPDF2
# !pip install reportlab
# !pip install svglib
# Out:
# Cloning into 'nss-report-v154-fix'...
# remote: Enumerating objects: 146, done.
# remote: Counting objects: 100% (146/146), done.
# remote: Compressing objects: 100% (113/113), done.
# remote: Total 146 (delta 27), reused 144 (delta 26), pack-reused 0
# Receiving objects: 100% (146/146), 44.96 MiB | 29.46 MiB/s, done.
# Resolving deltas: 100% (27/27), done.
# /content/nss-report-v154-fix/Report
# ...
#      |████████████████████████████████| 77 kB 3.5 MB/s
# ...
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-py3-none-any.whl size=61101 sha256=528c144eaf5742073d2fab8155637d6b0308c5351a0593481a4e232a02245bed
#   Stored in directory: /root/.cache/pip/wheels/80/1a/24/648467ade3a77ed20f35cfd2badd32134e96dd25ca811e64b3
# Successfully built PyPDF2
# ...
#      |████████████████████████████████| 2.7 MB 8.1 MB/s
# ...
#      |████████████████████████████████| 2.0 MB 6.8 MB/s
# ...

# %%
# !python main.py
# Out:
# /content/nss-report-v154-fix
# /content/nss-report-v154-fix/Report/Error_logs/main.txt is deleted successfully
# /content/nss-report-v154-fix/Report/Error_logs/SPV_main.txt is deleted successfully
# /content/nss-report-v154-fix/Report/Error_logs/LOGS.txt is deleted successfully
# Y100000001
# Record video type: mp4
# Successfully load 16 CSV Files
# ...
# (1/16) Now processing video: /content/nss-report-v154-fix/Result/20211109_Y100000001/190527_Y100000001.mp4 | test ID: Fixation suppression 5s
# Duration: 19 seconds
# ...
# (2/16) Now processing video: /content/nss-report-v154-fix/Result/20211109_Y100000001/184713_Y100000001.mp4 | test ID: Vertical saccade 1.0s (1.0Hz)
# Duration: 16 seconds
# ...
# (3/16) Now processing video: /content/nss-report-v154-fix/Result/20211109_Y100000001/190208_Y100000001.mp4 | test ID: Calibration 5s
# Duration: 15 seconds
# ...
# (4/16) Now processing video: /content/nss-report-v154-fix/Result/20211109_Y100000001/183417_Y100000001.mp4 | test ID: Horizontal pursuit 5s
# ...

# %% [markdown]
# ##👈👈👈Locate nss-report-v154-fix/Result/20211109_Y100000001/Report/NeuroSpeed_report.pdf and double-click download!
